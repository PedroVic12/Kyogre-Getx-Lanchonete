# %% [markdown]
# ## Cardapio Data

# %%
import pandas as pd

cardapio_df = pd.read_excel('./citta/Cardápio - 12.23.xlsx',skiprows=2)


def get_colunas(_dataframe):
    colunas = _dataframe.columns
    return colunas


display(cardapio_df.head(3))
# Out:
#   Açaí e Pitaya  300ml  500ml  Unnamed: 3                     Tapioca  PRECO  \
# 0          Açai   17.0   22.0         NaN  carne seca e queijo coalho   26.0
# 1        Pitaya   17.0   22.0         NaN     coco e leite condensado   22.0
# 2       Morango    3.0    3.0         NaN                Com Manteiga   13.0
#
#    Unnamed: 6                        Crepe  PRECO.1  Unnamed: 9  ...  \
# 0         NaN        Atum com Cream Cheese     28.0         NaN  ...
# 1         NaN     Carne Seca com Q. Coalho     28.0         NaN  ...
# 2         NaN  Frango, Palmito e Requeijão     27.0         NaN  ...
#
#   Unnamed: 41  Sopas Tradicionais  PRECOs Unnamed: 44          Pizzas  \
# 0         NaN         Caldo Verde    19.9         NaN  Quatro Queijos
# 1         NaN     Sopa de Legumes    19.9         NaN            Atum
# 2         NaN     Sopa de Ervilha    19.9         NaN      Bela Città
#
#                                        Igredientes.1 Brotinho  Média  Grande  \
# 0  Muçarela, Catupiry, Provolone, Queijo Prato, A...     20.9   26.9    34.9
# 1                   Muçarela, Atum, Cebola e Orégano      NaN    NaN     NaN
# 2  Muçarela, Tomate, Palmito, Ovo, Azeitona e Oré...      NaN    NaN     NaN
#
#   Familia
# 0    44.9
# 1     NaN
# 2     NaN
#
# [3 rows x 51 columns]

# %%
colunas_df = get_colunas(cardapio_df)

print(colunas_df)

colunas_dataframe = []

for i in colunas_df:
    colunas_dataframe.append(i)
# Out:
# Index(['Açaí e Pitaya', '300ml', '500ml', 'Unnamed: 3', 'Tapioca', 'PRECO',
#        'Unnamed: 6', 'Crepe', 'PRECO.1', 'Unnamed: 9', 'Omelete', 'PRECO.2',
#        'Unnamed: 12', 'Cuscuz de Milho', 'PRECO.3', 'Unnamed: 15',
#        'Hamburgueres Citta', 'PRECO.4', 'Unnamed: 18', 'Sobremesas (300ML)',
#        'PRECO.5', 'Unnamed: 21', 'Salgados', 'PRECO.6', 'Unnamed: 24',
#        'Sanduíche Natural', 'PRECO.7', 'Unnamed: 27',
#        'Sanduíches Tradicionais', 'Igredientes', 'PRECO.8', 'Unnamed: 31',
#        'Pratos Tradicionais', 'PRECO.9', 'Unnamed: 34', 'Pratos a la carte',
#        'PRECO.10', 'Unnamed: 37', 'Petiscos', 'Meia', 'Inteira', 'Unnamed: 41',
#        'Sopas Tradicionais', 'PRECOs', 'Unnamed: 44', 'Pizzas',
#        'Igredientes.1', 'Brotinho', 'Média', 'Grande', 'Familia'],
#       dtype='object')

# %%
array_table = []

for i in range(len(colunas_df)):
    tabela = cardapio_df[[colunas_df[i]]].dropna()
    array_table.append(tabela)
    if i == 2:
        break

def juntar_df():
    # Concatenar os DataFrames horizontalmente
    concatenated_df = pd.concat([array_table[0], array_table[1], array_table[2]], axis=1)

    # Exibir o DataFrame concatenado
    concatenated_df = concatenated_df.dropna()
    return concatenated_df
acai_df = juntar_df()



template = pd.read_excel('./citta/cardapio_template.xlsx',sheet_name='TEMPLATE')
template['NOME'] = acai_df[colunas_df[0]]
template['CATEGORIA'] = colunas_df[0]
template['preco_1'] = acai_df[colunas_df[1]]
template['preco_2'] = acai_df[colunas_df[2]]

display(template)
# Out:
#         NOME      CATEGORIA    SUB CAT  preco_1  preco_2 IGREDIENTES  IMAGEM  \
# 0       Açai  Açaí e Pitaya        NaN     17.0     22.0         NaN     NaN
# 1     Pitaya  Açaí e Pitaya        NaN     17.0     22.0         NaN     NaN
# 2    Morango  Açaí e Pitaya        NaN      3.0      3.0         NaN     NaN
# 3     Banana  Açaí e Pitaya        NaN      3.0      3.0         NaN     NaN
# 4    Granola  Açaí e Pitaya        NaN      4.0      4.0         NaN     NaN
# ..       ...            ...        ...      ...      ...         ...     ...
# 127      NaN  Açaí e Pitaya  Especiais      NaN      NaN         NaN     NaN
# 128      NaN  Açaí e Pitaya  Especiais      NaN      NaN         NaN     NaN
# 129      NaN  Açaí e Pitaya  Especiais      NaN      NaN         NaN     NaN
# 130      NaN  Açaí e Pitaya  Especiais      NaN      NaN         NaN     NaN
# 131      NaN  Açaí e Pitaya  Especiais      NaN      NaN         NaN     NaN
#
#      Unnamed: 7              CATEGORIA.1   ADICIONAIS  PRECO_ADD
# 0           NaN            Açaí e Pitaya     Morango         3.0
# 1           NaN            Açaí e Pitaya      Banana         3.0
# 2           NaN            Açaí e Pitaya     Granola         4.0
# 3           NaN            Açaí e Pitaya  Proteinato         4.0
# 4           NaN  Sanduíches Tradicionais       Salada        3.0
# ..          ...                      ...          ...        ...
# 127         NaN                      NaN          NaN        NaN
# 128         NaN                      NaN          NaN        NaN
# 129         NaN                      NaN          NaN        NaN
# 130         NaN                      NaN          NaN        NaN
# 131         NaN                      NaN          NaN        NaN
#
# [132 rows x 11 columns]

# %%
acai_df = cardapio_df['Açaí e Pitaya']
acai_300 = cardapio_df['300ml']
acai_500 = cardapio_df['500ml']

# Concatenar os DataFrames horizontalmente
concatenated_df = pd.concat([acai_df, acai_300, acai_500], axis=1)

# Exibir o DataFrame concatenado
concatenated_df.dropna()
# Out:
#   Açaí e Pitaya  300ml  500ml
# 0          Açai   17.0   22.0
# 1        Pitaya   17.0   22.0
# 2       Morango    3.0    3.0
# 3        Banana    3.0    3.0
# 4       Granola    4.0    4.0
# 5    Proteinato    4.0    4.0

# %% [markdown]
# ## 1) Automation

# %%
import os

def gerarJson(df, id):
    output_folder = 'cardapio_json'  # Nome da pasta de saída
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    json_data = df.to_json(orient='records', force_ascii=False)
    file_name = f'tabela_{id}.json'  # Nome do arquivo
    file_path = os.path.join(output_folder, file_name)  # Caminho completo do arquivo

    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(json_data)

    print(f'\nArquivo {file_name} salvo com sucesso!')

# %%
import pandas as pd



cardapio_df = pd.read_excel('./citta/Cardápio - 12.23.xlsx',skiprows=2)



def criar_tabelas_dinamicas(colunas, df, tabela_num=1):
    tabela_colunas = []
    tabela_valores = []

    tabelas = []

    for coluna in colunas:
        if 'Unnamed' in coluna:
            if tabela_colunas:
                tabela = pd.DataFrame({col: val for col, val in zip(tabela_colunas, tabela_valores)})
                tabela = tabela.dropna()
                tabelas.append(tabela)
                tabela_colunas = []
                tabela_valores = []
                tabela_num += 1
            continue

        tabela_colunas.append(coluna)
        tabela_valores.append(df[coluna])

    if tabela_colunas:
        tabela = pd.DataFrame({col: val for col, val in zip(tabela_colunas, tabela_valores)})
        tabela = tabela.dropna()
        tabelas.append(tabela)

    for tabela_df in tabelas:
        display(tabela_df)
        gerarJson(tabela_df, tabela_num)
        tabela_num += 1

    return tabelas


tabelas = criar_tabelas_dinamicas(colunas_dataframe, cardapio_df)

print('\nProcesso concluído.')
# Out:
#   Açaí e Pitaya  300ml  500ml
# 0          Açai   17.0   22.0
# 1        Pitaya   17.0   22.0
# 2       Morango    3.0    3.0
# 3        Banana    3.0    3.0
# 4       Granola    4.0    4.0
# 5    Proteinato    4.0    4.0
# Arquivo tabela_15.json salvo com sucesso!
#                       Tapioca  PRECO
# 0  carne seca e queijo coalho   26.0
# 1     coco e leite condensado   22.0
# 2                Com Manteiga   13.0
# 3           frango com queijo   23.0
# 4                    muçarela   20.0
# 5     peito de peru com minas   26.0
# 6               queijo coalho   24.0
# 7         Queijo com presunto   20.0
# 8                queijo minas   20.0
# 9                     Simples   12.0
# Arquivo tabela_16.json salvo com sucesso!
#                          Crepe  PRECO.1
# 0        Atum com Cream Cheese     28.0
# 1     Carne Seca com Q. Coalho     28.0
# 2  Frango, Palmito e Requeijão     27.0
# 3   Peito de Peru com Q. Minas     28.0
# 4          Queijo com Presunto     25.0
# Arquivo tabela_17.json salvo com sucesso!
#                       Omelete  PRECO.2
# 0       Atum com Cream Cheese     28.0
# 1  Peito de Peru com Q. Minas     28.0
# 2         Queijo com Presunto     21.0
# 3                Queijo Minas     24.0
# 4             Tomate e Cebola     21.0
# Arquivo tabela_18.json salvo com sucesso!
#   Cuscuz de Milho  PRECO.3
# 0        Recheado     18.0
# 1         Simples     14.0
# Arquivo tabela_19.json salvo com sucesso!
#         Hamburgueres Citta  PRECO.4
# 0               Hamburguer     13.0
# 1            CheeseBurguer     17.0
# 2             CheeseSalada     19.0
# 3              CheeseBacon     19.0
# 4        Egg CheeseBurguer     19.0
# 5  Egg Cheese com Presunto     20.0
# 6        Egg Cheese Salada     20.0
# 7         Egg Cheese Bacon     20.0
# 8            Città Sanduba     25.0
# 9                   X Tudo     23.0
# Arquivo tabela_20.json salvo com sucesso!
#        Sobremesas (300ML)  PRECO.5
# 0  Salada de Frutas 300ml     13.0
# 1  Salada de Frutas 500ml     15.0
# 2         Prato de Verão      28.0
# 3             Pudim Fatia     12.0
# 4             Torta Fatia     14.0
# Arquivo tabela_21.json salvo com sucesso!
#                   Salgados  PRECO.6
# 0  Batata frita 1/2 porção     18.9
# 1      Batata Frita Porçao     28.9
# 2           Fatia de Pizza     12.0
# 3       Pão Queijo Unidade      4.0
# 5        Salgados Diversos      9.0
# Arquivo tabela_22.json salvo com sucesso!
#   Sanduíche Natural  PRECO.7
# 0     Pasta de Atum     25.0
# 1   Pasta de Frango     22.0
# 3          Azeitona      2.0
# 4           Cenoura      2.0
# 5             Milho      2.0
# 6            Passas      2.0
# 7           Palmito      2.0
# Arquivo tabela_23.json salvo com sucesso!
#     Sanduíches Tradicionais                                      Igredientes  \
# 0                 Americano       Pão, Queijo Presunto, Ovo, Tomate e Alface
# 1                     Bauru  Pão, Queijo, Filé, Ovo, Tomate, Alface e Fritas
# 2             Filé de Carne                      Pão Francês e Filé de Carne
# 3            Filé de Frango                     Pão Francês e Filé de Frango
# 4              Misto Quente                  Pão de forma, Queijo e Presunto
# 5             Peito de Peru                        Pão árabe e Peito de Peru
# 6             Queijo Quente                            Pão de Forma e Queijo
# 7  Queijo Quente com Banana    Pão de forma, Queijo, Banana, Canela e Açucar
#
#    PRECO.8
# 0     24.0
# 1     42.0
# 2     30.0
# 3     27.0
# 4     16.0
# 5     25.0
# 6     16.0
# 7     19.0
# Arquivo tabela_24.json salvo com sucesso!
#           Pratos Tradicionais  PRECO.9
# 0             Carioca da Gema      0.0
# 1                Carne Assada      0.0
# 2          Picadinho de Carne      0.0
# 3              Bife Acebolado      0.0
# 4             Bife a Milanesa      0.0
# 5         Carne moída com ovo      0.0
# 6   Filé de frango à milanesa      0.0
# 7   Iscas de frango empanadas      0.0
# 8             Iscas de fígado      0.0
# 9   Coxa e Sobrecoxa ao Forno      0.0
# 10                      Carré      0.0
# 11   Bife de Fígado Acebolado      0.0
# 12     Filé de Peixe Empanado      0.0
# 13                Bife à rolé      0.0
# Arquivo tabela_25.json salvo com sucesso!
#                    Pratos a la carte  PRECO.10
# 0                  Filé à Brasileira         0
# 1              Filé à Oswaldo Aranha         0
# 2               Contra Filé à Gaúcha         0
# 3             Contra Filé à Campanha         0
# 4                  Filé à Parmegiana         0
# 5        Filé de Frango à Parmegiana         0
# 6           Escalopinho à Piamontese         0
# 7   Strogonoff de Carne ou de Frango         0
# 8           Filé de Tilápia Grelhada         0
# 9              Espaguete à Bolonhesa         0
# 10                           Lasanha         0
# 11          Espaguete com Almôndegas         0
# 12      Executivo de Carne ou Frango         0
# 13                Executivo de Peixe         0
# 14              Carne Seca à Mineira         0
# 15                      Batata Rosti         0
# 16                   Picanha à Citta         0
# 17                   Churrasco Misto         0
# Arquivo tabela_26.json salvo com sucesso!
#                                Petiscos  Meia  Inteira
# 0                  Provolone a Milanesa  24.9     42.9
# 1                           Aipim Frito  14.9     21.9
# 2                      Porção Salaminho  22.9     32.9
# 3                      Lingüiça Mineira  18.9     28.9
# 4                   Bolinho de Bacalhau  22.9     38.9
# 5                     Croquete de Carne  13.9     25.9
# 6   Gurjão a Milanesa - Peixe ou Frango  26.9     39.9
# 7                                Fritas  14.9     23.9
# 8             Fritas com Queijo e Bacon  19.9     28.9
# 9                   Calabresa Acebolada  17.9     28.9
# 10                  Frango à Passarinho  28.9     39.9
# 11               Contra Filé Apertitivo  28.9     48.9
# 12                   Espetinho na Chapa  23.9     43.9
# 13                          Pastelzinho  16.9     28.9
# Arquivo tabela_27.json salvo com sucesso!
#   Sopas Tradicionais  PRECOs
# 0        Caldo Verde    19.9
# 1    Sopa de Legumes    19.9
# 2    Sopa de Ervilha    19.9
# 3   Canja de Galinha    19.9
# 4       Feijão Amigo    19.9
# Arquivo tabela_28.json salvo com sucesso!
#            Pizzas                                      Igredientes.1  \
# 0  Quatro Queijos  Muçarela, Catupiry, Provolone, Queijo Prato, A...
#
#    Brotinho  Média  Grande  Familia
# 0      20.9   26.9    34.9     44.9
# Arquivo tabela_29.json salvo com sucesso!
#
# Processo concluído.

# %% [markdown]
# ## 2) Automate Base consolidada

# %%
import pandas as pd
import os

def gerarJson(df, id):
    output_folder = 'cardapio'  # Nome da pasta de saída
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    json_data = df.to_json(orient='records', force_ascii=False)
    file_name = f'tabela_{id}.json'  # Nome do arquivo
    file_path = os.path.join(output_folder, file_name)  # Caminho completo do arquivo

    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(json_data)

    print(f'\nArquivo {file_name} salvo com sucesso!')




df_consolidado = pd.read_excel('./citta/cardapio_template.xlsx')

df_consolidado = df_consolidado.iloc[:,:7]

produtos = df_consolidado['CATEGORIA'].value_counts()
print(produtos)
categorias = list(df_consolidado['CATEGORIA'].drop_duplicates())

ARRAY_PRODUTOS = []

for index in range(len(categorias)):
    df_filrado = df_consolidado.loc[ df_consolidado['CATEGORIA'] == categorias[index]]
    ARRAY_PRODUTOS.append(df_filrado)
    gerarJson(df_filrado,index)

ARRAY_PRODUTOS[7]
# Out:
# Sucos              53
# Bebidas            13
# Cafeteria          12
# Tapioca            10
# Hamburguer         10
# Sanduíches         10
# Crepe               5
# Omelete             5
# Sobremesas          5
# Salgados            5
# Açai e Pitaya       2
# Cuscuz de Milho     2
# Name: CATEGORIA, dtype: int64
#
# Arquivo tabela_0.json salvo com sucesso!
#
# Arquivo tabela_1.json salvo com sucesso!
#
# Arquivo tabela_2.json salvo com sucesso!
#
# Arquivo tabela_3.json salvo com sucesso!
#
# Arquivo tabela_4.json salvo com sucesso!
#
# Arquivo tabela_5.json salvo com sucesso!
#
# Arquivo tabela_6.json salvo com sucesso!
#
# Arquivo tabela_7.json salvo com sucesso!
#
# Arquivo tabela_8.json salvo com sucesso!
#
# Arquivo tabela_9.json salvo com sucesso!
#
# Arquivo tabela_10.json salvo com sucesso!
#
# Arquivo tabela_11.json salvo com sucesso!
#                        NOME CATEGORIA SUB_CAT  preco_1  preco_2 IGREDIENTES  \
# 39  Batata frita 1/2 porção  Salgados     NaN     18.9      NaN         NaN
# 40      Batata Frita Porçao  Salgados     NaN     28.9      NaN         NaN
# 41           Fatia de Pizza  Salgados     NaN     12.0      NaN         NaN
# 42       Pão Queijo Unidade  Salgados     NaN      4.0      NaN         NaN
# 43        Salgados Diversos  Salgados     NaN      9.0      NaN         NaN
#
#                IMAGEM
# 39                NaN
# 40                NaN
# 41  Icon(Icons.pizza)
# 42                NaN
# 43                NaN

# %%
filesProdutos = ARRAY_PRODUTOS[1]['IMAGEM']
display(filesProdutos)

files = filesProdutos.iloc[0]
files_list = files.split('|')
files_list = list(map(str.strip,files_list))

print(files_list)
# Out:
# 2     tapioca-carne-seca.png | Tapiocas (2).jpg |  T...
# 3                                      Tapiocas (3).jpg
# 4                                      Tapiocas (3).jpg
# 5                                      Tapiocas (3).jpg
# 6                                      Tapiocas (3).jpg
# 7                                      Tapiocas (3).jpg
# 8                                      Tapiocas (3).jpg
# 9                                      Tapiocas (3).jpg
# 10                                     Tapiocas (7).jpg
# 11                  Tapiocas (1).jpg | Tapiocas (3).jpg
# Name: IMAGEM, dtype: object
# ['tapioca-carne-seca.png', 'Tapiocas (2).jpg', 'Tapiocas (8).jpg']
